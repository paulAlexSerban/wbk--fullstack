# %%
import csv

with open('./find-the-link.csv', 'r') as csv_file:
    csv_reader = csv.reader(csv_file)
    link_string = ''

    for row_num, data in enumerate(csv_reader):\
        link_string += data[row_num]
        
    print(link_string)
# Out:
# https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q
