# %%
from PIL import Image

# %%
image = Image.open("/Users/paul.serban/Desktop/documents/repos/wbk--fullstack/workbook/02_web-development/frontend/wbk--frontend-playground/assets/media/source/images/ukulele.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=338x250>

# %%
# Cropping the image
cropped_image = image.crop((0, 0, 100, 100))
cropped_image
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
# rotate the image
rotated_image = image.rotate(45)
rotated_image
# Out:
# <PIL.Image.Image image mode=RGB size=338x250>

# %%
# add transparency
transparent_image = image.convert("RGBA")
transparent_image.putalpha(128)  # Set transparency level (0-255)
transparent_image
# Out:
# <PIL.Image.Image image mode=RGBA size=338x250>
